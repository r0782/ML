# %%
import pandas as pd
df=pd.read_csv("hotel-booking-data.txt")
print(df)
# Out:
#              Date\tCompany\tPerson Name\tRoom number
# 0        1-Jan-2022\tAvamba\tAnatole Ridehalgh\t4008
# 1            1-Jan-2022\tFatz\tAldrich McKevin\t2002
# 2           1-Jan-2022\tLeexo\tStanley Hadrill\t4012
# 3                                       Hotels\t\t\t
# 4             1-Jan-2022\tRhyzio\tLyndell Tice\t1006
# ..                                               ...
# 190                                  Cleartrip\t\t\t
# 191       1-Jan-2022\tFivechat\tCorabella Saye\t4008
# 192     1-Jan-2022\tInnojam\tLeandra Potapczuk\t5002
# 193  1-Jan-2022\tTwitterworks\tValentia Ledson\t1010
# 194                                     Hotels\t\t\t
#
# [195 rows x 1 columns]

# %%
print(df.head())# to print first five rows from the file
# Out:
#        Date\tCompany\tPerson Name\tRoom number
# 0  1-Jan-2022\tAvamba\tAnatole Ridehalgh\t4008
# 1      1-Jan-2022\tFatz\tAldrich McKevin\t2002
# 2     1-Jan-2022\tLeexo\tStanley Hadrill\t4012
# 3                                 Hotels\t\t\t
# 4       1-Jan-2022\tRhyzio\tLyndell Tice\t1006

# %%
print(df.tail())# to print the last five  rows from the file
# Out:
#              Date\tCompany\tPerson Name\tRoom number
# 190                                  Cleartrip\t\t\t
# 191       1-Jan-2022\tFivechat\tCorabella Saye\t4008
# 192     1-Jan-2022\tInnojam\tLeandra Potapczuk\t5002
# 193  1-Jan-2022\tTwitterworks\tValentia Ledson\t1010
# 194                                     Hotels\t\t\t

# %%
print(df.shape)# to print the shape of the data tables from the file
# Out:
# (195, 1)

# %%
print(df.columns)# to print the columns form the data
# Out:
# Index(['Date\tCompany\tPerson Name\tRoom number'], dtype='object')

# %%
print(df.dtypes)# to print the datatypes of the ojects from datatables
# Out:
# Date\tCompany\tPerson Name\tRoom number    object
# dtype: object

# %%
import pandas as pd

df = pd.read_csv("hotel-booking-data.txt", sep="\t")

print(df.columns)
# Out:
# Index(['Date', 'Company', 'Person Name', 'Room number'], dtype='object')

# %%
print(df[df["Room number"] > 25])
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 189  1-Jan-2022           NaN          Kylie Helin       5005.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [153 rows x 4 columns]
